# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
from scipy.stats import zscore
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
sns.set()

# %%
with open('P1- BankStatements.json') as P1:
    data=json.load(P1)

# %%
type(data)
# Out:
# dict

# %%
len(data)
# Out:
# 1

# %%
df1=pd.DataFrame(data)
df1
# Out:
#                                                               Account
# type                                                          deposit
# maskedAccNumber                                              XXXX6461
# version                                                           1.1
# linkedAccRef                     02f28b8d-d8a3-43d7-88c6-5fabb2e51541
# xmlns                        http://api.rebit.org.in/FISchema/deposit
# xsi:schemaLocation       http://api.rebit.org.in/FISchema/deposit.xsd
# xmlns:xsi                   http://www.w3.org/2001/XMLSchema-instance
# Profile             {'Holders': {'type': 'SINGLE', 'Holder': {'nam...
# Summary             {'currentBalance': '761.41', 'currency': 'INR'...
# Transactions        {'startDate': '2023-05-31', 'endDate': '2024-0...

# %% [markdown]
# ### 1) Transaction Analysis:
# #### a) What is the total number of transactions made over the year?

# %%
tra=data['Account']['Transactions']['Transaction']
len(tra)
# Out:
# 985

# %%
df=pd.DataFrame(tra)
df = df.sort_values(by='transactionTimestamp')
df.head()
# Out:
#      type    mode  amount currentBalance       transactionTimestamp  \
# 0   DEBIT    CARD   100.0        2180.80  2023-06-27T09:40:19+05:30
# 1   DEBIT    CARD   170.0        2010.80  2023-06-28T09:51:57+05:30
# 2   DEBIT    CARD   500.0        1510.80  2023-07-26T10:04:00+05:30
# 3  CREDIT  OTHERS    15.0        1525.80  2023-08-06T11:10:38+05:30
# 4   DEBIT     ATM  1000.0         525.80  2023-08-07T17:13:13+05:30
#
#     valueDate      txnId                                    narration  \
# 0  2023-06-27  S39488701        PRCR/MS NEHA FILLING STATIO/FARRUKHAB
# 1  2023-06-28  S76862822        PRCR/MS NEHA FILLING STATIO/FARRUKHAB
# 2  2023-07-26  S31451661        PRCR/MS NEHA FILLING STATIO/FARRUKHAB
# 3  2023-07-31  S66463256  51888100006461IntPd01-05-2023 to 31-07-2023
# 4  2023-08-07  S18475743       ATM/CASH/321917012791/XXXXXXXXXXXX8896
#
#   reference
# 0        NA
# 1        NA
# 2        NA
# 3        NA
# 4        NA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  985 non-null    object
#  1   mode                  985 non-null    object
#  2   amount                985 non-null    object
#  3   currentBalance        985 non-null    object
#  4   transactionTimestamp  985 non-null    object
#  5   valueDate             985 non-null    object
#  6   txnId                 985 non-null    object
#  7   narration             985 non-null    object
#  8   reference             985 non-null    object
# dtypes: object(9)
# memory usage: 69.4+ KB

# %%
# # Save DataFrame to CSV
# csv_file = 'transactions.csv'
# df.to_csv(csv_file, index=False)

# # Code to download the CSV file if running in a Jupyter notebook
# from IPython.display import FileLink
# FileLink(csv_file)

# %% [markdown]
# #### b) What is the distribution of transaction amounts (e.g., small vs. large transactions)?(define small and large transactions by yourself)

# %%
df['amount'] = df['amount'].astype(float)
am=df['amount']
am.describe()
# Out:
# count      985.000000
# mean       855.492802
# std       3007.515100
# min          1.000000
# 25%         40.000000
# 50%        160.000000
# 75%        500.000000
# max      45000.000000
# Name: amount, dtype: float64

# %%
am.median()
# Out:
# 160.0

# %%
q1 = am.quantile(0.25)
q3 = am.quantile(0.75)

q1, q3
# Out:
# (40.0, 500.0)

# %%
# Define small, medium, and large transactions
def categorize_transaction(amount):
    if amount < q1:
        return 'Small'
    elif amount <= q3:
        return 'Medium'
    else:
        return 'Large'

df['transaction_size'] = df['amount'].apply(categorize_transaction)

plt.figure(figsize=(7, 6))
sns.countplot(x='transaction_size', data=df,hue='transaction_size', palette='Set2',order=['Small','Medium','Large'])
plt.legend(['40<=amount<=500','amount<40','amount>500'])

plt.title('Distribution of Transaction Amounts')
plt.ylabel('Number of Transactions')

plt.show()

# %% [markdown]
# #### c) Analyze the frequency of different transaction types (debit vs. credit).

# %%
df['type'].value_counts()
# Out:
# type
# DEBIT     695
# CREDIT    290
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='type', data=df,hue='type', palette='Set2')
plt.show()

# %% [markdown]
# ### 2) Balance Analysis

# %%
df['currentBalance']=df['currentBalance'].astype(float)
cb=df['currentBalance']

# %%
df['valueDate']=pd.to_datetime(df["valueDate"],format='mixed')
vd=df['valueDate']
df.head()
# Out:
#      type    mode  amount  currentBalance       transactionTimestamp  \
# 0   DEBIT    CARD   100.0          2180.8  2023-06-27T09:40:19+05:30
# 1   DEBIT    CARD   170.0          2010.8  2023-06-28T09:51:57+05:30
# 2   DEBIT    CARD   500.0          1510.8  2023-07-26T10:04:00+05:30
# 3  CREDIT  OTHERS    15.0          1525.8  2023-08-06T11:10:38+05:30
# 4   DEBIT     ATM  1000.0           525.8  2023-08-07T17:13:13+05:30
#
#    valueDate      txnId                                    narration  \
# 0 2023-06-27  S39488701        PRCR/MS NEHA FILLING STATIO/FARRUKHAB
# 1 2023-06-28  S76862822        PRCR/MS NEHA FILLING STATIO/FARRUKHAB
# 2 2023-07-26  S31451661        PRCR/MS NEHA FILLING STATIO/FARRUKHAB
# 3 2023-07-31  S66463256  51888100006461IntPd01-05-2023 to 31-07-2023
# 4 2023-08-07  S18475743       ATM/CASH/321917012791/XXXXXXXXXXXX8896
#
#   reference transaction_size
# 0        NA           Medium
# 1        NA           Medium
# 2        NA           Medium
# 3        NA            Small
# 4        NA            Large

# %% [markdown]
# #### a) What is the trend of the account balance over time?
# #### b) Identify any periods with significant changes in the account balance.

# %%
plt.figure(figsize=(10, 7))
plt.plot(vd, cb, linestyle='-')
plt.xlabel('Date')
plt.ylabel('Current Balance')
plt.title('Trend of Account Balance Over Time')
plt.show()

# %% [markdown]
# ###  3) Spending Patterns
# #### a) What are the main categories of expenses (e.g., fuel, Ecommerce, food, shopping, ATM withdrawals, UPI transactions)?

# %%
md=df['mode']

# %%
md.unique()
# Out:
# array(['CARD', 'OTHERS', 'ATM', 'UPI', 'CASH'], dtype=object)

# %%
md.value_counts()
# Out:
# mode
# UPI       789
# OTHERS    188
# CARD        4
# ATM         3
# CASH        1
# Name: count, dtype: int64

# %% [markdown]
# #### b) Analyze the frequency and amount of spending in each category.

# %%
sns.countplot(x='mode',data=df,hue='mode',palette='Set2',edgecolor='k')
plt.ylabel('Frequency')
plt.show()

# %%
sum_by_mode=df.groupby('mode')['amount'].sum().reset_index()

# %%
sum_by_mode
# Out:
#      mode     amount
# 0     ATM   13500.00
# 1    CARD     830.00
# 2    CASH   45000.00
# 3  OTHERS  196237.51
# 4     UPI  587092.90

# %%
sns.barplot(x='mode',y='amount', data=sum_by_mode,hue='mode',edgecolor='k')
plt.show()

# %% [markdown]
# ### 4.  Income Analysis:
# #### a) What are the main sources of income (e.g., salary, UPI credits)?

# %%
credit_transactions = df[df['type'] == 'CREDIT'].copy()
credit_transactions['narration'].unique()
# Out:
# array(['51888100006461IntPd01-05-2023 to 31-07-2023',
#        'UPI/323441197152/114914/UPI/8795417446ybl/Paym',
#        'UPI/323457106254/122004/UPI/9264998949barodamp',
#        'UPI/323567840697/105122/UPI/kimoroybl/Payment',
#        'UPI/323602109737/113218/UPI/9701028466ibl/Paym',
#        'UPI/323618540670/123136/UPI/9580229953axl/Paym',
#        'UPI/323628493930/165253/UPI/7479893801ibl/Paym',
#        'UPI/323679308931/182222/UPI/7731035157ibl/Paym',
#        'UPI/360354864566/160316/UPI/mayankbhai73590oki',
#        'IMPS/P2A/323716492303/PHONEPEPRIVATEL/IMPSAXB9111',
#        'UPI/323784208807/161921/UPI/goog-paymentokaxis',
#        'NEFT-AXNPN32379238097-PHONEPE PRIVATE LIMITED',
#        'IMPS/P2A/323718489753/PHONEPEPRIVATEL/IMPSAXB9111',
#        'UPI/323802960783/192600/UPI/9369558521ybl/Paym',
#        'UPI/323823651280/194229/UPI/rajanbhai271okhdfc',
#        'UPI/323840766196/203616/UPI/shivampandit199999',
#        'UPI/323906382845/192938/UPI/atulyadav16469axl/',
#        'IMPS/P2A/324020918876/PHONEPEPRIVATEL/IMPSAXB9111',
#        'IMPS/P2A/324120778985/PHONEPEPRIVATEL/IMPSAXB9111',
#        'IMPS/P2A/324216087923/PHONEPEPRIVATEL/IMPSAXB9111',
#        'IMPS/P2A/324220033063/PHONEPEPRIVATEL/IMPSAXB9111',
#        'NEFT-AXNPN32436146561-PHONEPE PRIVATE LIMITED-PAYM',
#        'IMPS/P2A/324313262601/PHONEPEPRIVATEL/IMPSAXB9111',
#        'UPI/360922384154/160911/UPI/6393130981paytm/NA',
#        'UPI/361211837275/181909/UPI/8318404822ybl/Paym',
#        'UPI/324796646064/121018/UPI/akashk4478oksbi/UP',
#        'IMPS/P2A/324719156719/PHONEPEPRIVATEL/IMPSAXB9111',
#        'UPI/324834305504/163009/UPI/7310728269ibl/Paym',
#        'IMPS/P2A/324816104223/PHONEPEPRIVATEL/IMPSAXB9111',
#        'IMPS/P2A/325120711629/PHONEPEPRIVATEL/IMPSAXB9111',
#        'NEFT-AXNPN32522537728-PHONEPE PRIVATE LIMITED-PAYM',
#        'IMPS/P2A/325220633774/PHONEPEPRIVATEL/IMPSAXB9111',
#        'NEFT-AXNPN32551072344-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32564161171-PHONEPE PRIVATE LIMITED-PAYM',
#        'IMPS/P2A/325619237951/PHONEPEPRIVATEL/IMPSAXB9111',
#        'IMPS/P2A/325719401444/PHONEPEPRIVATEL/IMPSAXB9111',
#        'IMPS/P2A/325721171918/PHONEPEPRIVATEL/IMPSAXB9111',
#        'IMPS/P2A/325819277159/PHONEPEPRIVATEL/IMPSAXB9111',
#        'IMPS/P2A/325823524705/PHONEPEPRIVATEL/IMPSAXB9111',
#        'UPI/362682097837/201752/UPI/9140092527ybl/Paym',
#        'IMPS/P2A/326122069839/PHONEPEPRIVATEL/IMPSAXB9111',
#        'NEFT-AXNPN32647896963-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/326459300319/182939/UPI/8178328660ybl/Paym',
#        'UPI/326414745806/192825/UPI/8178328660ybl/Paym',
#        'NEFT-AXNPN32663243361-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32689715249-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/326845678397/174150/UPI/8423410441ybl/Paym',
#        'UPI/326955781096/140054/UPI/pammapamma651okhdf',
#        'UPI/327056465788/120606/UPI/7786043828axl/Paym',
#        'NEFT-AXNPN32707366582-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32718772376-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32721951358-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32735104122-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32748433244-PHONEPE PRIVATE LIMITED-PAYM',
#        'IMPS/P2A/327419437183/PHONEPEPRIVATEL/IMPSAXB9111',
#        'IMPS/P2A/327423909113/PHONEPEPRIVATEL/IMPSAXB9111',
#        'NEFT-AXNPN32764818020-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32778269663-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32781741064-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/327899560520/184846/UPI/mr2484066okaxis/UP',
#        'UPI/364515185408/180917/UPI/9837552268ybl/Paym',
#        'UPI/327996855768/213010/UPI/9315118386ibl/Paym',
#        'NEFT-AXNPN32809040627-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/364771401449/201008/UPI/8795417446ybl/Paym',
#        'NEFT-AXNPN32826017756-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/364879513820/200219/UPI/8795417446ybl/Paym',
#        'NEFT-AXNPN32839436761-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32843162277-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32856873127-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/328501902949/182553/UPI/9696594120ibl/Paym',
#        'NEFT-AXNPN32860530042-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32891631905-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32905135003-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32919277330-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32940698673-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN32968158203-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/329687708432/222316/UPI/9315118386ibl/Paym',
#        'NEFT-AXNPN32971658637-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/329719192683/204514/UPI/pranshusrivastava85',
#        'NEFT-AXNPN32985362621-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33016178125-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/366728204872/164150/UPI/914009252754paytm/',
#        'NEFT-AXNPN33033295421-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/330335699567/185352/UPI/7458942407ibl/Paym',
#        'NEFT-AXNPN33065053054-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/331098721834/192032/UPI/7458942407ibl/Paym',
#        'NEFT-AXNPN33115403433-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33121803511-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/331239380432/152122/UPI/9315118386ibl/Paym',
#        '51888100006461IntPd01-08-2023 to 31-10-2023',
#        'NEFT-AXNPN33134581345-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/331316876773/165628/UPI/gopalbatham796axl/',
#        'NEFT-AXNPN33149187715-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33153901636-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/331588799730/233230/UPI/9315118386ibl/Paym',
#        'NEFT-AXNPN33168292220-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/331830889030/172320/UPI/aditya9450203ybl/P',
#        'UPI/331873302771/182921/UPI/311999sshuklaaxl/P',
#        'UPI/331812106847/183112/UPI/311999sshuklaaxl/P',
#        'UPI/368570135513/121030/REVERSAL',
#        'NEFT-AXNPN33203710382-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/368618153232/123302/UPI/payoutspaytm/20231', 'BY CASH',
#        'NEFT-AXNPN33217638945-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33235789141-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33249383441-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33254474828-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33267548354-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33271645925-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/332796236369/214233/UPI/anupamshakya2807-1',
#        'UPI/369365682733/214629/UPI/sainiharsh8737891',
#        'NEFT-AXNPN33285739683-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33290184240-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33303815768-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33317453486-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33321994185-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/369811008163/130205/UPI/9119906554ybl/Paym',
#        'NEFT-AXNPN33336248163-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/369910143175/191526/UPI/8795417446ybl/Paym',
#        'NEFT-AXNPN33354387161-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33368654568-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33373186693-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33387264701-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33391170193-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/370786267324/102324/UPI/7860606760ibl/Paym',
#        'NEFT-AXNPN33424653823-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33439210579-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33443412565-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33457550249-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33461895162-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33476737709-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33481108384-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33509669133-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33513397481-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/335186799080/103116/UPI/shivangdwivedi427o',
#        'NEFT-AXNPN33528038027-PHONEPE PRIVATE LIMITED-PAYM',
#        'IMPS/P2A/335219855298/PHONEPEPRIVATEL/IMPSAXB9111',
#        'NEFT-AXNPN33546662187-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33551284935-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/335528082440/152353/UPI/payoutspaytm/20231',
#        'NEFT-AXNPN33565583691-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33570013984-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33584447789-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/335973197398/121223/UPI/shivangdwivedi427o',
#        'UPI/335925943300/130425/UPI/goog-paymentokaxis',
#        'NEFT-AXNPN33602337168-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33616881110-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33621080639-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33635402991-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN33654400751-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/373135141185/164102/UPI/6386923805ibl/Paym',
#        'NEFT-AXNPN40018693141-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/436734007951/183800/UPI/9910619719ibl/Paym',
#        'IMPS/P2A/400118123422/PHONEPEPRIVATEL/IMPSAXB9111',
#        'UPI/400130671636/195435/UPI/rk5282872oksbi/UPI',
#        'NEFT-AXNPN40037669598-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40042250767-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40061458299-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40080707738-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40100149349-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/437669522726/210134/UPI/9451168065ybl/Paym',
#        'UPI/437612889834/210625/UPI/9451168065ybl/Paym',
#        'NEFT-AXNPN40129380265-PHONEPE PRIVATE LIMITED-PAYM',
#        'IMPS/P2A/401218945872/PHONEPEPRIVATEL/IMPSAXB9111',
#        'NEFT-AXNPN40148769252-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40167082884-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/401682428368/213514/UPI/amaankhanfbd1ybl/P',
#        'NEFT-AXNPN40205732267-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40210525110-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40242398567-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40260945206-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40275270663-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40289411150-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40293250185-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/402951045257/210749/UPI/shivampandit199999',
#        'NEFT-AXNPN40307831851-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40312286488-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/439702920595/191758/UPI/shivampandit199999',
#        'NEFT-AXNPN40326715012-PHONEPE PRIVATE LIMITED-PAYM',
#        '51888100006461IntPd01-11-2023 to 31-01-2024',
#        'UPI/403447957327/185339/UPI/ksonu433477okicici',
#        'NEFT-AXNPN40351071566-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40390150217-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN40419484619-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/404269427688/214010/UPI/shivampandit199999',
#        'NEFT-AXNPN40438685742-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/440961634787/132257/UPI/8795417446ybl/Paym',
#        'NEFT-AXNPN40457808985-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/404658902080/195925/UPI/dubeyadharvoksbi/U',
#        'UPI/441279546319/204729/UPI/8318914152ybl/Paym',
#        'NEFT-AXNPN40492895372-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/405016448388/130104/UPI/mayankbhai73590oki',
#        'UPI/441761496027/125040/UPI/9910619719ybl/Paym',
#        'NEFT-AXNPN40533478873-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/442192582411/185516/UPI/8795417446-2ybl/Pa',
#        'UPI/405522192936/192626/UPI/dubeyadharvoksbi/U',
#        'UPI/405647910397/142207/UPI/dubeyadharvoksbi/U',
#        'UPI/442272156503/200859/UPI/8318914152ybl/Paym',
#        'UPI/405977407689/125541/UPI/dubeyadharvoksbi/U',
#        'UPI/442551593707/152703/UPI/9910619719ybl/Paym',
#        'UPI/442927378643/172316/UPI/9140092527ybl/Paym',
#        'UPI/406404593963/140340/UPI/dubeyadharvoksbi/U',
#        'UPI/406404667972/140529/UPI/dubeyadharvoksbi/U',
#        'UPI/443283731179/152347/UPI/sirajmohd23ibl/Pa',
#        'UPI/443231436454/152531/UPI/sirajmohd23axl/Pa',
#        'UPI/443253653663/171208/UPI/9910619719ibl/Paym',
#        'NEFT-AXNPN07236221944-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN07346182027-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/444045776225/192206/UPI/9119906554-2ybl/Pa',
#        'NEFT-AXNPN07565943484-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN07675649505-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN07785291996-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN07894176291-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN07903656851-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN08013228203-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN08123043186-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN08232507646-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/444841401061/084752/UPI/8318914152ybl/Paym',
#        'NEFT-AXNPN08451764733-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/408454786813/183050/UPI/8178328660ybl/Paym',
#        'UPI/445156560833/203820/UPI/8726128640ybl/Paym',
#        'UPI/445447800624/171205/UPI/sajalgupta123ybl/P',
#        'UPI/445453420833/194558/UPI/6386098404ibl/Paym',
#        'NEFT-AXNPN08993522184-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN09107889601-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/409149527852/121502/UPI/bobbyshakya76788486',
#        'UPI/445816921965/183241/UPI/9580265955ybl/Paym',
#        'IMPS/P2A/409223023408/PHONEPEPRIVATEL/IMPSAXB9111',
#        'UPI/445622203499/RET/30032024',
#        'NEFT-AXNPN09423821251-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN09751220727-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN09860526863-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/409890320950/195220/UPI/mohitkingguptaokax',
#        'NEFT-AXNPN10078490209-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN10187448879-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN10296849616-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN10304642528-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/410362944187/204745/UPI/8960920752ibl/Paym',
#        'NEFT-AXNPN10413139173-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/447027427446/145653/UPI/80776452910ybl/Pay',
#        'NEFT-AXNPN10629944424-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN10738834356-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN10847845753-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN11065444663-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN11174599533-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN11283758485-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN11392698261-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN11401782717-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN11510876467-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/411507708698/120647/UPI/bflautopayhdfcbank',
#        'NEFT-AXNPN11620067677-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN11729650056-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN11837826782-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN11947635585-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/448513094529/192324/UPI/rboy32851okicici/U',
#        'UPI/411981597069/192438/UPI/rboy32851okhdfcban',
#        'NEFT-AXNPN12056089599-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN12165089763-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN12274224174-PHONEPE PRIVATE LIMITED-PAYM',
#        '51888100006461IntPd01-02-2024 to 30-04-2024',
#        'NEFT-AXNPN12383850372-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN12492944519-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN12502718447-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN12612305141-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN12720906959-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN12830349193-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/449476496945/134811/UPI/9910619719ibl/Paym',
#        'NEFT-AXNPN12939183247-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/449561148445/215226/UPI/8318914152axl/Paym',
#        'IMPS/P2A/413019342635/PHONEPEPRIVATEL/IMPSAXB9111',
#        'UPI/449714971666/085830/UPI/abhishekshakya8172',
#        'NEFT-AXNPN13269302343-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN13378172709-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN13487029272-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN13606008279-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN13715616213-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/413743064071/195836/UPI/8115504793nehajiyb',
#        'NEFT-AXNPN13824410081-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/450601898350/121541/UPI/8303922846ibl/Paym',
#        'NEFT-AXNPN14261608351-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN14371290011-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/450963336655/202149/UPI/sajalgupta123ybl/P',
#        'NEFT-AXNPN14480896873-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/414515790893/193350/REVERSAL',
#        'NEFT-AXNPN14699634650-PHONEPE PRIVATE LIMITED-PAYM',
#        'IMPS/P2A/414622757146/ONE97COMMUNICAT/IMPSAXB9199',
#        'NEFT-AXNPN14927376982-PHONEPE PRIVATE LIMITED-PAYM',
#        'NEFT-AXNPN15036609374-PHONEPE PRIVATE LIMITED-PAYM',
#        'UPI/415061496542/171043/UPI/7786043828ibl/Paym',
#        'NEFT-AXNPN15145877034-PHONEPE PRIVATE LIMITED-PAYM'], dtype=object)

# %%
source_mapping = {
    '5188': 'Interest',
    'UPI/': 'UPI',
    'IMPS': 'IMPS',
    'NEFT': 'NEFT',
    'BY C': 'Cash'
}
credit_transactions['source'] = credit_transactions['narration'].apply(lambda x: source_mapping.get(x[:4], 'Other'))
credit_transactions.head()
# Out:
#       type    mode  amount  currentBalance       transactionTimestamp  \
# 3   CREDIT  OTHERS    15.0          1525.8  2023-08-06T11:10:38+05:30
# 6   CREDIT     UPI  3000.0          3524.8  2023-08-22T11:49:13+05:30
# 7   CREDIT     UPI   300.0          3824.8  2023-08-22T12:20:04+05:30
# 9   CREDIT     UPI   400.0          3024.8  2023-08-23T10:51:21+05:30
# 10  CREDIT     UPI   500.0          3524.8  2023-08-24T11:32:18+05:30
#
#     valueDate      txnId                                       narration  \
# 3  2023-07-31  S66463256     51888100006461IntPd01-05-2023 to 31-07-2023
# 6  2023-08-22  S90667553  UPI/323441197152/114914/UPI/8795417446ybl/Paym
# 7  2023-08-22  S92051775  UPI/323457106254/122004/UPI/9264998949barodamp
# 9  2023-08-23  S25232032   UPI/323567840697/105122/UPI/kimoroybl/Payment
# 10 2023-08-24  S65206796  UPI/323602109737/113218/UPI/9701028466ibl/Paym
#
#    reference transaction_size    source
# 3         NA            Small  Interest
# 6         NA            Large       UPI
# 7         NA           Medium       UPI
# 9         NA           Medium       UPI
# 10        NA           Medium       UPI

# %%
Income_Based = credit_transactions.groupby('source')['amount'].sum().reset_index()
ax=sns.barplot(x='source', y='amount', data=Income_Based,hue='source')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# #### b) Identify any patterns in the timing and amount of income received.

# %%
# 4.2 Patterns in Timing and Amount of Income Received
credit_transactions['month'] = credit_transactions['valueDate'].dt.to_period('M')
monthly_income = credit_transactions.groupby('month')['amount'].sum()

monthly_income.plot(kind='line',marker='o')
plt.xlabel('Month')
plt.ylabel('Total Income')
plt.title('Monthly Income Pattern')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 5. Alert Generation
# #### a) Identify any unusual or suspicious transactions.

# %%
df['currentBalance'].describe()
# Out:
# count      985.000000
# mean      5901.308721
# std       8670.950436
# min          0.800000
# 25%       1174.800000
# 50%       2723.110000
# 75%       5834.110000
# max      58450.800000
# Name: currentBalance, dtype: float64

# %% [markdown]
# #### b) Generate alerts for low balance or high expenditure periods.

# %%
# 1) Identify Unusual Transactions

# Calculating the Z-scores of the transaction amounts to identify outliers
df['amount_zscore'] = zscore(df['amount'].abs())
unusual_transactions = df[df['amount_zscore'] > 3]


# 2) Alerts for Low Balance
low_balance_threshold = 1174.8  # 25th Percentile (25%): 1174.800000
low_balance_alerts = df[df['currentBalance'] < low_balance_threshold]


# 3: Alerts for High Expenditure
# Calculating the rolling sum of expenditures over a 7-day window

df['transactionTimestamp'] = pd.to_datetime(df['transactionTimestamp'])
df = df.sort_values(by='transactionTimestamp')
df['expenditure'] = df.apply(lambda x: x['amount'] if x['type'] == 'DEBIT' else 0, axis=1)
df.set_index('transactionTimestamp', inplace=True)
df['rolling_expenditure'] = df['expenditure'].rolling('7D').sum()
df.reset_index(inplace=True)


# Defining a high expenditure threshold
rolling_mean = df['rolling_expenditure'].mean()
rolling_std = df['rolling_expenditure'].std()

high_expenditure_threshold = rolling_mean + 2 * rolling_std
high_expenditure_alerts = df[df['rolling_expenditure'] > high_expenditure_threshold]

# %% [markdown]
# ### Unusual Transcations

# %%
print("\nUnusual Transactions:\n")
print(unusual_transactions[['transactionTimestamp', 'amount', 'amount_zscore']])
# Out:
# Unusual Transactions:
#
#           transactionTimestamp   amount  amount_zscore
# 275  2023-11-14T18:31:11+05:30  37999.0      12.356505
# 277  2023-11-14T18:49:41+05:30  16500.0       5.204448
# 285  2023-11-15T17:48:21+05:30  10000.0       3.042097
# 291  2023-11-16T15:51:14+05:30  45000.0      14.685523
# 295  2023-11-17T16:34:54+05:30  21000.0       6.701459
# 332  2023-11-29T16:15:33+05:30  19000.0       6.036121
# 333  2023-11-29T17:09:47+05:30  12700.0       3.940304
# 353  2023-12-05T15:50:06+05:30  13000.0       4.040105
# 535  2024-02-12T13:22:57+05:30  10000.0       3.042097
# 537  2024-02-13T14:01:51+05:30  10000.0       3.042097
# 570  2024-02-24T18:55:15+05:30  20000.0       6.368790
# 572  2024-02-25T11:08:34+05:30  20000.0       6.368790
# 576  2024-02-25T20:08:58+05:30  20000.0       6.368790
# 648  2024-03-20T18:56:48+05:30  12000.0       3.707436
# 743  2024-04-12T20:47:44+05:30  30000.0       9.695483
# 744  2024-04-12T20:50:06+05:30  30000.0       9.695483
# 884  2024-05-13T06:54:41+05:30  11530.0       3.551081
# 889  2024-05-14T11:51:56+05:30  10000.0       3.042097

# %%
# Plot of unusual transactions
plt.figure(figsize=(10, 6))
plt.plot(df['transactionTimestamp'], df['amount'], label='Transaction Amount')
plt.scatter(unusual_transactions['transactionTimestamp'], unusual_transactions['amount'], color='red', label='Unusual Transactions')
plt.title('Unusual Transactions')
plt.xlabel('Transaction Timestamp')
plt.ylabel('Amount')
plt.legend()
plt.show()

# %% [markdown]
# ### Low balance alerts

# %%
print("\nLow Balance Alerts:\n")
print(low_balance_alerts[['transactionTimestamp', 'currentBalance']])
# Out:
# Low Balance Alerts:
#
#           transactionTimestamp  currentBalance
# 4    2023-08-07T17:13:13+05:30          525.80
# 5    2023-08-22T08:05:06+05:30          524.80
# 18   2023-08-25T10:39:35+05:30          794.80
# 19   2023-08-25T12:03:11+05:30          674.80
# 20   2023-08-25T16:03:16+05:30         1154.80
# ..                         ...             ...
# 980  2024-05-29T17:57:40+05:30           23.41
# 981  2024-05-30T05:07:05+05:30          961.41
# 982  2024-05-30T09:58:24+05:30          901.41
# 983  2024-05-30T13:30:30+05:30          771.41
# 984  2024-05-30T13:38:20+05:30          761.41
#
# [246 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['transactionTimestamp'], df['currentBalance'], label='Current Balance')
plt.scatter(low_balance_alerts['transactionTimestamp'], low_balance_alerts['currentBalance'], color='orange', label='Low Balance Alerts')
plt.title('Low Balance Alerts')
plt.xlabel('Transaction Timestamp')
plt.ylabel('Current Balance')
plt.legend()
plt.show()

# %% [markdown]
# ### High expenditure alerts

# %%
print("\nHigh Expenditure Alerts:\n")
print(high_expenditure_alerts[['transactionTimestamp', 'rolling_expenditure']])
# Out:
# High Expenditure Alerts:
#
#          transactionTimestamp  rolling_expenditure
# 285 2023-11-15 17:48:21+05:30              39601.0
# 286 2023-11-15 19:08:47+05:30              40101.0
# 287 2023-11-15 20:56:36+05:30              40111.0
# 288 2023-11-16 05:34:18+05:30              40061.0
# 289 2023-11-16 12:33:01+05:30              40061.0
# ..                        ...                  ...
# 762 2024-04-17 20:39:39+05:30              41010.9
# 763 2024-04-18 13:09:44+05:30              40235.0
# 764 2024-04-19 06:58:16+05:30              39885.0
# 765 2024-04-19 19:35:04+05:30              39335.0
# 766 2024-04-19 20:23:27+05:30              39355.0
#
# [68 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['transactionTimestamp'], df['rolling_expenditure'], label='Rolling 7-Day Expenditure')
plt.scatter(high_expenditure_alerts['transactionTimestamp'], high_expenditure_alerts['rolling_expenditure'], color='green', label='High Expenditure Alerts')
plt.title('High Expenditure Alerts')
plt.xlabel('Transaction Timestamp')
plt.ylabel('Rolling 7-Day Expenditure')
plt.legend()
plt.show()

# %%
df.head()
# Out:
#        transactionTimestamp    type    mode  amount  currentBalance  \
# 0 2023-06-27 09:40:19+05:30   DEBIT    CARD   100.0          2180.8
# 1 2023-06-28 09:51:57+05:30   DEBIT    CARD   170.0          2010.8
# 2 2023-07-26 10:04:00+05:30   DEBIT    CARD   500.0          1510.8
# 3 2023-08-06 11:10:38+05:30  CREDIT  OTHERS    15.0          1525.8
# 4 2023-08-07 17:13:13+05:30   DEBIT     ATM  1000.0           525.8
#
#    valueDate      txnId                                    narration  \
# 0 2023-06-27  S39488701        PRCR/MS NEHA FILLING STATIO/FARRUKHAB
# 1 2023-06-28  S76862822        PRCR/MS NEHA FILLING STATIO/FARRUKHAB
# 2 2023-07-26  S31451661        PRCR/MS NEHA FILLING STATIO/FARRUKHAB
# 3 2023-07-31  S66463256  51888100006461IntPd01-05-2023 to 31-07-2023
# 4 2023-08-07  S18475743       ATM/CASH/321917012791/XXXXXXXXXXXX8896
#
#   reference transaction_size  amount_zscore  expenditure  rolling_expenditure
# 0        NA           Medium      -0.251329        100.0                100.0
# 1        NA           Medium      -0.228042        170.0                270.0
# 2        NA           Medium      -0.118262        500.0                500.0
# 3        NA            Small      -0.279606          0.0                  0.0
# 4        NA            Large       0.048073       1000.0               1000.0
